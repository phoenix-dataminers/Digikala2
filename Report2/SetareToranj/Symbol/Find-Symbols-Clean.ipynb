# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My\ Drive/SetareToranj
# Out:
# /content/gdrive/My Drive/SetareToranj

# %%
df = pd.read_excel('digi_clean_final.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  ... catg_dislikes
# 0           1  ...           -75
# 1           2  ...           -75
# 2           3  ...           -75
# 3           4  ...           -75
# 4           5  ...           -75
#
# [5 rows x 14 columns]

# %%
#Fill NaN in title column
df['comment'].fillna('فیلد خالی است', inplace=True)
df['title'].fillna('فیلد خالی است', inplace=True)
df['advantages'].fillna('فیلد خالی است', inplace=True)
df['disadvantages'].fillna('فیلد خالی است', inplace=True)

# %% [markdown]
# ##symbols on comment column

# %%
res1c = df[df.comment.astype(str).str.contains('\?')]
res1c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 1062         1100  ...           -75
# 11807       14898  ...           -75
# 36815       47960  ...           -75
# 42174       55342  ...           -75
# 63321       85448  ...           -75
#
# [5 rows x 14 columns]

# %%
print('Number of comments contain ? mark:' ,len(res1c))
# Out:
# Number of comments contain ? mark: 5

# %%
res2c = df[df.comment.astype(str).str.contains('\؟')]
res2c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 160           164  ...           -75
# 398           406  ...           -75
# 973          1004  ...           -75
# 1077         1116  ...           -75
# 1435         1524  ...           -75
# ...           ...  ...           ...
# 72011       97840  ...           -75
# 72210       98116  ...           -75
# 72412       98419  ...           -75
# 73198       99585  ...           -75
# 73298       99738  ...           -75
#
# [332 rows x 14 columns]

# %%
print('Number of comments contain ؟ mark:' ,len(res2c))
# Out:
# Number of comments contain ؟ mark: 332

# %%
res3c = df[df.comment.astype(str).str.contains('!')]
res3c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 34             35  ...           -75
# 39             40  ...           -75
# 43             44  ...           -75
# 70             72  ...           -75
# 81             83  ...           -75
# ...           ...  ...           ...
# 73352       99818  ...           -75
# 73361       99837  ...           -75
# 73366       99845  ...           -75
# 73410       99904  ...           -75
# 73438       99941  ...           -75
#
# [3259 rows x 14 columns]

# %%
print('Number of comments contain ! mark:' ,len(res3c))
# Out:
# Number of comments contain ! mark: 3259

# %%
res4c = df[df.comment.astype(str).str.contains('\$')]
res4c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 63599       85837  ...           -75
#
# [1 rows x 14 columns]

# %%
print('Number of comments contain $ mark:' ,len(res4c))
# Out:
# Number of comments contain $ mark: 1

# %%
res5c = df[df.comment.astype(str).str.contains('&')]
res5c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 342           350  ...           -75
# 4035         4919  ...           -75
# 8526        10672  ...           -75
# 12638       15994  ...           -75
# 19226       24595  ...           -75
# 21438       27628  ...           -75
# 24473       31601  ...           -75
# 32135       41678  ...           -75
# 33475       43453  ...           -75
# 33609       43636  ...           -75
# 38536       50356  ...           -75
# 45733       60248  ...           -75
# 50349       66637  ...           -75
# 51072       67665  ...           -75
# 56039       74764  ...           -75
# 63132       85176  ...           -75
# 64143       86637  ...           -75
# 69369       94034  ...           -75
#
# [18 rows x 14 columns]

# %%
print('Number of comments contain & mark:' ,len(res5c))
# Out:
# Number of comments contain & mark: 18

# %%
res6c = df[df.comment.astype(str).str.contains('#')]
res6c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 651           670  ...           -75
# 926           955  ...           -75
# 1895         2081  ...           -75
# 2440         2832  ...           -75
# 3018         3597  ...           -75
# ...           ...  ...           ...
# 67941       92010  ...           -75
# 68103       92245  ...           -75
# 68949       93462  ...           -75
# 72724       98875  ...           -75
# 72749       98915  ...           -75
#
# [66 rows x 14 columns]

# %%
print('Number of comments contain # mark:' ,len(res6c))
# Out:
# Number of comments contain # mark: 66

# %%
res7c = df[df.comment.astype(str).str.contains('%')]
res7c
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of comments contain % mark:' ,len(res7c))
# Out:
# Number of comments contain % mark: 0

# %%
import re
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
               "]+")
emo1c = df[df.comment.astype(str).str.contains(emoji_pattern)]
emo1c
# Out:
#        Unnamed: 0  ... catg_dislikes
# 424           433  ...           -75
# 650           669  ...           -75
# 1853         2030  ...           -75
# 5274         6524  ...           -75
# 10040       12600  ...           -75
# 11794       14883  ...           -75
# 12590       15927  ...           -75
# 13078       16550  ...           -75
# 22474       28974  ...           -75
# 24527       31670  ...           -75
# 27616       35682  ...           -75
# 27697       35796  ...           -75
# 27712       35822  ...           -75
# 27965       36139  ...           -75
# 27982       36161  ...           -75
# 30001       38853  ...           -75
# 30074       38947  ...           -75
# 30216       39146  ...           -75
# 33606       43632  ...           -75
# 35643       46353  ...           -75
# 43992       57850  ...           -75
# 54857       73000  ...           -75
# 56945       76148  ...           -75
# 56978       76197  ...           -75
# ...

# %%
print('Number of comments contain emojies:' ,len(emo1c))
# Out:
# Number of comments contain emojies: 29

# %%
x = ['?','؟','!','$','&','#','%','Emojies']
y = [len(res1c),len(res2c),len(res3c),len(res4c),len(res5c),len(res6c),len(res7c),len(emo1c)]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
# From here the plotting starts
plt.yticks(np.arange(min(y), max(y)+1, 250))
# plt.yticks(np.arange(0, 4200, 420))
plt.scatter(x, y, c='r', label='dot')
plt.plot(x, y, label='line')
plt.xlabel('Symbols')
plt.ylabel('Comment Number')
plt.title('Symbols plot')
plt.legend()
plt.show()

# %%
# plt.pie(y)

fig, ax = plt.subplots(figsize=(9, 24), subplot_kw=dict(aspect="equal"))

recipe = ["5 comment ?",
          "332 comment ؟",
          "3259 comment !",
          "1 comment $",
          "18 comment &",
          "66 comment #",
          "0 comment %",
          "29 comment emojies"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100000)
    return " "


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Symbols",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Symbol Rate in comments")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(22,10), subplot_kw=dict(aspect="equal"))

recipe = ["? Symbol",
          "؟ Symbol" ,
          "! Symbol",
          "$ Symbol",
          "& Symbol",
          "# Symbol",
          "% Symbol",
          "emojies Symbol"]


data = [5, 332, 3259, 1, 18, 66, 0, 29]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=20)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %% [markdown]
# ##symbols on title column

# %%
res1t = df[df.title.astype(str).str.contains('\?')]
res1t
# Out:
#        Unnamed: 0                   product_title  ... catg_likes  catg_dislikes
# 56948       76152      ساعت هوشمند وی سریز مدل V8  ...        -75            -75
# 66782       90343  کرم ضد جوش AC.NET لامینین 30ml  ...        -75            -75
#
# [2 rows x 14 columns]

# %%
print('Number of titles contain ? mark:' ,len(res1t))
# Out:
# Number of titles contain ? mark: 2

# %%
res2t = df[df.title.astype(str).str.contains('\؟')]
res2t
# Out:
#        Unnamed: 0  ... catg_dislikes
# 3530         4259  ...           -75
# 3532         4261  ...           -75
# 3994         4864  ...           -75
# 4674         5732  ...           -75
# 5746         7139  ...           -75
# 6512         8132  ...           -75
# 6776         8459  ...           -75
# 7082         8844  ...           -75
# 7614         9529  ...           -75
# 7680         9607  ...           -75
# 8333        10431  ...           -75
# 8970        11243  ...           -75
# 10174       12767  ...           -75
# 14313       18199  ...           -75
# 14599       18564  ...           -75
# 15508       19730  ...           -75
# 16652       21222  ...           -75
# 17705       22601  ...           -75
# 20046       25650  ...           -75
# 22610       29158  ...           -75
# 24221       31260  ...           -75
# 26422       34125  ...           -75
# 28260       36526  ...           -75
# 30279       39235  ...           -75
# ...

# %%
print('Number of titles contain ؟ mark:' ,len(res2t))
# Out:
# Number of titles contain ؟ mark: 55

# %%
res3t = df[df.title.astype(str).str.contains('!')]
res3t
# Out:
#        Unnamed: 0  ... catg_dislikes
# 150           154  ...           -75
# 283           290  ...           -75
# 357           365  ...           -75
# 397           405  ...           -75
# 399           407  ...           -75
# ...           ...  ...           ...
# 73120       99464  ...           -75
# 73155       99521  ...           -75
# 73286       99721  ...           -75
# 73298       99738  ...           -75
# 73385       99867  ...           -75
#
# [693 rows x 14 columns]

# %%
print('Number of titles contain ! mark:' ,len(res3t))
# Out:
# Number of titles contain ! mark: 693

# %%
res4t = df[df.title.astype(str).str.contains('\$')]
res4t
# Out:
#        Unnamed: 0  ... catg_dislikes
# 11060       13928  ...           -75
#
# [1 rows x 14 columns]

# %%
print('Number of titles contain $ mark:' ,len(res4t))
# Out:
# Number of titles contain $ mark: 1

# %%
res5t = df[df.title.astype(str).str.contains('&')]
res5t
# Out:
#        Unnamed: 0  ... catg_dislikes
# 8098        10130  ...           -75
# 13104       16582  ...           -75
# 24730       31944  ...           -75
# 34437       44734  ...           -75
#
# [4 rows x 14 columns]

# %%
print('Number of titles contain & mark:' ,len(res5t))
# Out:
# Number of titles contain & mark: 4

# %%
res6t = df[df.title.astype(str).str.contains('#')]
res6t
# Out:
#        Unnamed: 0  ... catg_dislikes
# 94             96  ...           -75
# 515           528  ...           -75
# 786           810  ...           -75
# 1039         1076  ...           -75
# 1672         1802  ...           -75
# ...           ...  ...           ...
# 72749       98915  ...           -75
# 72869       99086  ...           -75
# 73182       99561  ...           -75
# 73362       99839  ...           -75
# 73444       99951  ...           -75
#
# [376 rows x 14 columns]

# %%
print('Number of titles contain # mark:' ,len(res6t))
# Out:
# Number of titles contain # mark: 376

# %%
res7t = df[df.title.astype(str).str.contains('%')]
res7t
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of titles contain % mark:' ,len(res7t))
# Out:
# Number of titles contain % mark: 0

# %%
import re
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
               "]+")
emo1t = df[df.title.astype(str).str.contains(emoji_pattern)]
emo1t
# Out:
#        Unnamed: 0  ... catg_dislikes
# 1595         1713  ...           -75
# 13078       16550  ...           -75
# 27803       35939  ...           -75
# 44315       58301  ...           -75
# 72393       98388  ...           -75
#
# [5 rows x 14 columns]

# %%
print('Number of titles contain emojies:' ,len(emo1t))
# Out:
# Number of titles contain emojies: 5

# %% [markdown]
# ##symbols on advantages column

# %%
res1a = df[df.advantages.astype(str).str.contains('\?')]
res1a
# Out:
#        Unnamed: 0              product_title  ... catg_likes  catg_dislikes
# 41988       55097  هندزفری بلوتوث مدل HBQ-I7  ...        -75            -75
#
# [1 rows x 14 columns]

# %%
print('Number of advantages contain ? mark:' ,len(res1a))
# Out:
# Number of advantages contain ? mark: 1

# %%
res2a = df[df.advantages.astype(str).str.contains('\؟')]
res2a
# Out:
#        Unnamed: 0  ... catg_dislikes
# 5045         6216  ...           -75
# 8581        10742  ...           -75
# 9050        11346  ...           -75
# 13856       17601  ...           -75
# 32397       42026  ...           -75
# 36229       47146  ...           -75
# 44040       57917  ...           -75
# 51688       68509  ...           -75
# 69405       94081  ...           -75
# 72808       99000  ...           -75
#
# [10 rows x 14 columns]

# %%
print('Number of advantages contain ؟ mark:' ,len(res2a))
# Out:
# Number of advantages contain ؟ mark: 10

# %%
res3a = df[df.advantages.astype(str).str.contains('!')]
res3a
# Out:
#        Unnamed: 0  ... catg_dislikes
# 714           734  ...           -75
# 1018         1054  ...           -75
# 1055         1093  ...           -75
# 1594         1712  ...           -75
# 2341         2688  ...           -75
# ...           ...  ...           ...
# 68548       92911  ...           -75
# 69612       94391  ...           -75
# 70661       95878  ...           -75
# 71207       96671  ...           -75
# 71950       97755  ...           -75
#
# [112 rows x 14 columns]

# %%
print('Number of advantages contain ! mark:' ,len(res3a))
# Out:
# Number of advantages contain ! mark: 112

# %%
res4a = df[df.advantages.astype(str).str.contains('\$')]
res4a
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of advantages contain $ mark:' ,len(res4a))
# Out:
# Number of advantages contain $ mark: 0

# %%
res5a = df[df.advantages.astype(str).str.contains('&')]
res5a
# Out:
#        Unnamed: 0  ... catg_dislikes
# 444           453  ...           -75
# 17327       22110  ...           -75
# 42891       56327  ...           -75
# 50354       66643  ...           -75
#
# [4 rows x 14 columns]

# %%
print('Number of advantages contain & mark:' ,len(res5a))
# Out:
# Number of advantages contain & mark: 4

# %%
res6a = df[df.advantages.astype(str).str.contains('#')]
res6a
# Out:
#        Unnamed: 0  ... catg_dislikes
# 47             48  ...           -75
# 76             78  ...           -75
# 125           129  ...           -75
# 144           148  ...           -75
# 155           159  ...           -75
# ...           ...  ...           ...
# 73118       99461  ...           -75
# 73142       99494  ...           -75
# 73158       99524  ...           -75
# 73226       99624  ...           -75
# 73448       99958  ...           -75
#
# [1104 rows x 14 columns]

# %%
print('Number of advantages contain # mark:' ,len(res6a))
# Out:
# Number of advantages contain # mark: 1104

# %%
res7a = df[df.advantages.astype(str).str.contains('%')]
res7a
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of advantages contain % mark:' ,len(res7a))
# Out:
# Number of advantages contain % mark: 0

# %%
import re
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
               "]+")
emo1a = df[df.advantages.astype(str).str.contains(emoji_pattern)]
emo1a
# Out:
#        Unnamed: 0                     product_title  ... catg_likes  catg_dislikes
# 19988       25567                   روسری مدل Eliza  ...        -75            -75
# 34738       45139  رژگونه این لی مدل Peach شماره 03  ...        -75            -75
#
# [2 rows x 14 columns]

# %%
print('Number of advantages contain emojies:' ,len(emo1a))
# Out:
# Number of advantages contain emojies: 2

# %% [markdown]
# ##symbols on disadvantages column

# %%
res1d = df[df.disadvantages.astype(str).str.contains('\?')]
res1d
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of disadvantages contain ? mark:' ,len(res1d))
# Out:
# Number of disadvantages contain ? mark: 0

# %%
res2d = df[df.disadvantages.astype(str).str.contains('\؟')]
res2d
# Out:
#        Unnamed: 0  ... catg_dislikes
# 2144         2418  ...           -75
# 7807         9764  ...           -75
# 9303        11661  ...           -75
# 11491       14493  ...           -75
# 14193       18037  ...           -75
# 15394       19588  ...           -75
# 15411       19614  ...           -75
# 17548       22402  ...           -75
# 19582       25053  ...           -75
# 23925       30880  ...           -75
# 27079       34980  ...           -75
# 35584       46278  ...           -75
# 36685       47770  ...           -75
# 36796       47937  ...           -75
# 43207       56784  ...           -75
# 46628       61504  ...           -75
# 47093       62150  ...           -75
# 53081       70513  ...           -75
# 58443       78353  ...           -75
# 59990       80564  ...           -75
# 61125       82262  ...           -75
# 62011       83545  ...           -75
# 63419       85607  ...           -75
# 65565       88627  ...           -75
# ...

# %%
print('Number of disadvantages contain ؟ mark:' ,len(res2d))
# Out:
# Number of disadvantages contain ؟ mark: 26

# %%
res3d = df[df.disadvantages.astype(str).str.contains('!')]
res3d
# Out:
#        Unnamed: 0  ... catg_dislikes
# 60             61  ...           -75
# 136           140  ...           -75
# 204           208  ...           -75
# 308           316  ...           -75
# 445           454  ...           -75
# ...           ...  ...           ...
# 71122       96542  ...           -75
# 71554       97187  ...           -75
# 71831       97594  ...           -75
# 72312       98265  ...           -75
# 73460       99983  ...           -75
#
# [225 rows x 14 columns]

# %%
print('Number of disadvantages contain ! mark:' ,len(res3d))
# Out:
# Number of disadvantages contain ! mark: 225

# %%
res4d = df[df.disadvantages.astype(str).str.contains('\$')]
res4d
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of disadvantages contain $ mark:' ,len(res4d))
# Out:
# Number of disadvantages contain $ mark: 0

# %%
res5d = df[df.disadvantages.astype(str).str.contains('&')]
res5d
# Out:
#        Unnamed: 0  ... catg_dislikes
# 56710       75773  ...           -75
#
# [1 rows x 14 columns]

# %%
print('Number of disadvantages contain & mark:' ,len(res5d))
# Out:
# Number of disadvantages contain & mark: 1

# %%
res6d = df[df.disadvantages.astype(str).str.contains('#')]
res6d
# Out:
#        Unnamed: 0  ... catg_dislikes
# 0               1  ...           -75
# 5               6  ...           -75
# 12             13  ...           -75
# 15             16  ...           -75
# 16             17  ...           -75
# ...           ...  ...           ...
# 73386       99870  ...           -75
# 73395       99880  ...           -75
# 73396       99882  ...           -75
# 73421       99916  ...           -75
# 73445       99953  ...           -75
#
# [2860 rows x 14 columns]

# %%
print('Number of disadvantages contain # mark:' ,len(res6d))
# Out:
# Number of disadvantages contain # mark: 2860

# %%
res7d = df[df.disadvantages.astype(str).str.contains('%')]
res7d
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_title, title_en, likes, dislikes, recommend, title, comment, advantages, disadvantages, comment_len, word_count, catg_likes, catg_dislikes]
# Index: []

# %%
print('Number of disadvantages contain % mark:' ,len(res7d))
# Out:
# Number of disadvantages contain % mark: 0

# %%
import re
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
               "]+")
emo1d = df[df.disadvantages.astype(str).str.contains(emoji_pattern)]
emo1d
# Out:
#        Unnamed: 0  ... catg_dislikes
# 2578         3015  ...           -75
# 33381       43322  ...           -75
# 37444       48846  ...           -75
# 46987       62010  ...           -75
# 56945       76148  ...           -75
# 64369       86953  ...           -75
# 70210       95239  ...           -75
#
# [7 rows x 14 columns]

# %%
print('Number of disadvantages contain emojies:' ,len(emo1d))
# Out:
# Number of disadvantages contain emojies: 7
