# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My\ Drive/Digikala
# Out:
# /content/gdrive/My Drive/Digikala

# %%
df = pd.read_excel('Digi_2.xlsx')

# %%
#Fill NaN in title column
df['comment'].fillna('فیلد خالی است', inplace=True)
df['title'].fillna('فیلد خالی است', inplace=True)
df['advantages'].fillna('فیلد خالی است', inplace=True)
df['disadvantages'].fillna('فیلد خالی است', inplace=True)

# %%
df.isna().any()
# Out:
# product_id             False
# product_title          False
# title_en               False
# user_id                False
# likes                  False
# dislikes               False
# verification_status    False
# recommend              False
# title                  False
# comment                False
# advantages             False
# disadvantages          False
# dtype: bool

# %% [markdown]
# ##Symbols in Comments

# %%
res1 = df[df.comment.astype(str).str.contains('\?')]
res1
# Out:
#        product_id  ...                                      disadvantages
# 1100       133916  ...  [" فکوس دستی اگه چرخشی بود و روش کار میکردن عا...
# 14898      121304  ...                                   ["صدای موزیک. "]
# 47960      319868  ...                                      فیلد خالی است
# 54228      308023  ...                                           ["هیچی"]
# 55342      739109  ...                                          ["گرما "]
# 85448      868030  ...                             ["نبودن لیگ قهرمانان"]
#
# [6 rows x 12 columns]

# %%
print('Number of comments contain ? mark:' ,len(res1))
# Out:
# Number of comments contain ? mark: 6

# %%
#check a comment to see the mark
df.comment.loc[55342]
# Out:
# 'بنده وقتی با لپ تاپم بازی میکنم با این که کول پد زیرش گزاشتم ولی گرمای بیش از حدی رو از قسمت کناریش حس میکنم.این توی تمام لپ تاپ ها هست پس چیز نرمالی فقط ی نکته کوجیک میمونه این گرمای بیش از حد بعد از طولانی مدن به قطعات اسیب میزنه و به تجربه گیمینگ خدشه وارد میکنه (حداقل برای من)میپرسید چرا?چون مدام برام عادت شده که وسط بازی دستمو کنار بدنه لپ تاپ بگیرم که ی وقت گرماش بیش از حد نشه.به طور کلی لپ تاپ مناسب گیمینگ توی رویا وجود داره.هیچ لپ تاپی مناسب گیمینگ نیست.این نکته رو هم قید کنم که اصولا لپ تاپ یک وسیله پرتابله یعنی شما میتونی جابجاش کنی اما لپ تاپ های گیمینگ که بعد از نیم ساعت بازی و فشار سنگین باتری خالی میکنن چه جوری پرتابل و قابل حمل محسوب میشن'

# %%
res2 = df[df.comment.astype(str).str.contains('\؟')]
res2
# Out:
#        product_id  ...                                      disadvantages
# 164         68247  ...  ["باتری ضعیف(توضیح خواهم داد)\r","ماندن اثر ان...
# 406        172917  ...                                      فیلد خالی است
# 1004       309366  ...                                      فیلد خالی است
# 1116        20401  ...                                      فیلد خالی است
# 1524       216749  ...                                      فیلد خالی است
# ...           ...  ...                                                ...
# 98419      376718  ...                                      فیلد خالی است
# 98429      370197  ...                                      فیلد خالی است
# 98432      369175  ...                                      فیلد خالی است
# 99585      339175  ...  ["قرص از توری باک رد نمیشه\r","باک ماشینا معمو...
# 99738      259514  ...                                      فیلد خالی است
#
# [423 rows x 12 columns]

# %%
print('Number of comments contain ؟ mark:' ,len(res2))
# Out:
# Number of comments contain ؟ mark: 423

# %%
#check a comment to see the mark
df.comment.loc[1524]
# Out:
# 'سلام من یکسال بیشتر است این گوشی رو دارم. نمیدونم بعصی از دوستان چرا نظر الکی میدن؟؟ جوری که ادم شک میکنه بهشون که انگار این گوشی رو تو دست هم نگرفتن.\r\nمورد اول اونی که میگه تاچ ضعیفی داره. اتفاقا تاچش اینقدر حساس هست که گاهی اوقات با نزدیک شدن دست هم کار میکنه. اگه مال شما دیر عمل میکنه برید توی تنظیمات و قدرت لمس رو زیاد قرار بدید. و تا از چیزی مطمئن نشدید الکی نظر ندید و مردم رو گمراه نکنید.\r\nاون دوستی که میگه دیر شارژ میشه. مال من 50 دقیقه با شارژر اصلیش به صد درصد میرسه مال دوستای دیگه م یکم بیشتر طول میکشه حدود هفتاد دقیقه. دلیلشم اینه مال من چون اولین سری بود شارژرش سه پایه است و هندسفری فوق العاده با کیفیتی داره که مال دوستای دیگم هندسفری بی کیفیت و شارژر دوپایه داره.\r\nاون دوستایی که میگن دوربینش خوب نیست حالت hdrدوربین رو توی شب خاموش کنید و نور شب گوشیرو روشن کنید همون که توی منو عکس ماه رو داراست. \r\nبدون تعصب چون این گوشی پردازنده ی خوبی داره هنگ نمیکنه و خیلی روانه.\r\nاندروید 9 هم تا چند روز دیگه واسه ی گوشی میاد و کسایی که اپدیت نکردن تا حالا . میتونن از سایت م
# ...

# %%
res3 = df[df.comment.astype(str).str.contains('!')]
res3
# Out:
#        product_id  ...                                      disadvantages
# 35         154624  ...                         ["باد کردن بعد از دو سال"]
# 40          55495  ...                                      فیلد خالی است
# 44         127328  ...                ["با برنامه Lte Watch سازگار نیست"]
# 72         180591  ...                                            ["هیچ"]
# 83         166853  ...                     ["وارد شدن سرما از بخش جلویی"]
# ...           ...  ...                                                ...
# 99818      535595  ...                                       ["کمی گران"]
# 99837      543523  ...                                      فیلد خالی است
# 99845      204678  ...                                      فیلد خالی است
# 99904      901961  ...                                      فیلد خالی است
# 99941       56642  ...  ["نبود لوازم اضاف مانند لنس و تفنگی کف پاش خوب...
#
# [4169 rows x 12 columns]

# %%
print('Number of comments contain ! mark:' ,len(res3))
# Out:
# Number of comments contain ! mark: 4169

# %%
#check a comment to see the mark
df.comment.loc[44]
# Out:
# 'من این مودم رو یک ساله دارم واقعاااا بی نظیره.همه سیم کارتا روش جواب میده\r\nاین مودم قابلیت LTE Only هم داره که میتونین روی شبکه 4G قفل کنید که توی محله ما این امکان خیلی خوبه چون تو گوشی ۴جی فقط یه خط آنتن میده و سریع سوئیچ میشه رو ۳جی\r\nتنها ضعفی که دیدم نمیشه مثل مودم های هواوی به برنامه lte watch  متصلش کرد تا جژییات آنتن دهی رو مشاهده کرد\r\nما تو خونه این مودم رو خانوادگی استفاده میکنیم و همیشه بصورت ۲۴ ساعته روشنه و هیچ ایرادی هم ندیدم تا حالا!!!\r\nراسی یه قابلیت هم داره که میتونی تعین بکنی تا چند گیگ یا مگ که اینترنت استفاده شد دیتا رو قطع کنه!!البته این امکان برای مصرف کل مودم هست ! نه برای یه شخص خاص'

# %%
res4 = df[df.comment.astype(str).str.contains('\$')]
res4
# Out:
#        product_id  ...                                      disadvantages
# 85837      221119  ...  ["هیچ کاری جز پردازندش نمی کند و قابلیت اضافه ...
#
# [1 rows x 12 columns]

# %%
print('Number of comments contain $ mark:' ,len(res4))
# Out:
# Number of comments contain $ mark: 1

# %%
#check a comment to see the mark
df.comment.loc[85837]
# Out:
# 'این را دو سالی هست دارم اگر نیاز به کار هایی که نیاز به پردازندش خیلی سنگین ندارید منظورم کار هایی که حداقل 128gb رم می خواهند که البته باید برای این کار ها به سراغ پردازنده های بالا 2000$ بروید اقتصادی ترین پردازنده است.بسته بودن عزیزان عیب بود دیگه با آمدن مادربرد های atuo oveloack دیگر مهم نیست مگر این که خیلی خیلی حرفه ای باشید دقیق بدانید ضرایب تغییر بدهید.در ضمن این پردازندش گرفیکی داخلیش اگه نبود به نظر بهتر بود چون اگر طرف این را می خرد قطعا کار ش حرفه تر از این حرف هاست که بدون کارت گرافیک راه بیفتد برای سیستم های معمولی هم برای چه باید i7استفاده کرد.'

# %%
res5 = df[df.comment.astype(str).str.contains('&')]
res5
# Out:
#        product_id  ...                                      disadvantages
# 350        263989  ...                                           ["قیمت"]
# 1850       276977  ...                                      فیلد خالی است
# 4919       152262  ...                                      فیلد خالی است
# 10672      359042  ...                                      فیلد خالی است
# 15994      200769  ...  ["نسخه بلوتوث پایین\r","کیفیت صدا راضی کننده ن...
# 24595      180451  ...       ["ارتباط برقرار کردن سخت با گوشی های مختلف"]
# 27628      637564  ...                                      فیلد خالی است
# 31601      327934  ...                                      فیلد خالی است
# 41678      318566  ...                                      فیلد خالی است
# 43453      670447  ...                                      فیلد خالی است
# 43636      326909  ...                                      فیلد خالی است
# 50356      689675  ...                                      فیلد خالی است
# ...

# %%
print('Number of comments contain & mark:' ,len(res5))
# Out:
# Number of comments contain & mark: 22

# %%
#check a comment to see the mark
df.comment.loc[74764]
# Out:
# 'اصلا لبتاپ خوبی نیست!!! من توصیه میکنم اصلا نخرید. چون من اولش از دیجی کالا نظراتو دیدم تو پیشنهاد شگفت انگیز بود. بخاطر قیمت کمش پیشنهاد شده بود. بعد از خرید دو سه ماه بعد بدون هیچ ضربه و ... هاردش بسکتور داشت. صفحه نمایشش هم مات نیست فورا کثیف میشه. کیفیت صفحه نمایش هم در حد صفره . چن تا گیم مث pes & need for speed هم زدم هیچکدوم باز نکرد. خلاصه یه لبتابه معمولی هستش با قیمت بالا .'

# %%
res6 = df[df.comment.astype(str).str.contains('#')]
res6
# Out:
#        product_id  ...                                      disadvantages
# 670        225046  ...  ["صفحه نمایش در زیر نور آفتاب به سختی دیده میش...
# 955        319868  ...                                          ["ندارد"]
# 2081       658282  ...                                      فیلد خالی است
# 2686       617151  ...                                      فیلد خالی است
# 2832       399474  ...                                      فیلد خالی است
# ...           ...  ...                                                ...
# 90230      492860  ...                                         ["آشغاله"]
# 90751      348928  ...                                     ["هیچی نداره"]
# 92245      842976  ...                                      فیلد خالی است
# 93462      273452  ...  ["محل قرارگیری فنهای خنک کننده\r","\r","\r","\...
# 98875       90999  ...                                      فیلد خالی است
#
# [68 rows x 12 columns]

# %%
print('Number of comments contain # mark:' ,len(res6))
# Out:
# Number of comments contain # mark: 68

# %%
#check a comment to see the mark
df.comment.loc[2832]
# Out:
# 'بسیار زیبا و دارای طراحی دقیق و مدرن میباشد؛ با قیمت شگفت انگیز هم که دیگه فوق العاده است. سپاس از دیجی کالا\r\n#نظرتومهمه'

# %%
res7 = df[df.comment.astype(str).str.contains('%')]
res7
# Out:
#        product_id  ...                                      disadvantages
# 491        143866  ...  ["نداشتن صفحه نمایش جهت نشون دادن شارژ خود پاو...
# 1919       201873  ...                                       ["شارژ کند"]
# 2336        34755  ...                                      فیلد خالی است
# 2476       279730  ...                      ["تا حالا چیزی به چشم ندیدم"]
# 3216       316893  ...  ["کانتنت کم\r","نیاز به Nat Type A\/B \r","سرو...
# ...           ...  ...                                                ...
# 98269      427185  ...                                      فیلد خالی است
# 99486      412840  ...                      ["پایه رومیزی نه چندان جالب"]
# 99684      221333  ...                                           ["هیچی"]
# 99747      762833  ...                           ["فکر نمیکم داشته باشه"]
# 99856      859802  ...                                      فیلد خالی است
#
# [178 rows x 12 columns]

# %%
print('Number of comments contain % mark:' ,len(res7))
# Out:
# Number of comments contain % mark: 178

# %%
#check a comment to see the mark
df.comment.loc[98269]
# Out:
# 'متاسفانه تو مشخصات کالا درج شده 100% پنبه در حالی که توی این تیشرت مقدار زیادی نایلون به کار رفته امیدوارم این مورد رو اصلاح کنن تا بقیه مثل من به مشکل بر نخورن!'

# %% [markdown]
# ## Find Emojis

# %%
import re
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
               "]+")
emo1 = df[df.comment.astype(str).str.contains(emoji_pattern)]
emo1
# Out:
#        product_id  ...                                      disadvantages
# 433        222547  ...                                                 []
# 669        341893  ...                                     ["کیفیت ساخت"]
# 2030        93850  ...  ["فقط یه کوچولو مشکل تو نرم افزار هست که اونم ...
# 4151       207991  ...                                      فیلد خالی است
# 6524       115461  ...                                      فیلد خالی است
# 7223       535505  ...                                      فیلد خالی است
# 12600      197789  ...                                      فیلد خالی است
# 14883      518194  ...                                      فیلد خالی است
# 15927       81124  ...                                                 []
# 16550      695765  ...                                      فیلد خالی است
# 20469      522433  ...                                          ["نداره"]
# 28974      134500  ...                                      فیلد خالی است
# ...

# %%
print('Number of comments contain emojies:' ,len(emo1))
# Out:
# Number of comments contain emojies: 42

# %%
#check a comment to see the mark
df.comment.loc[38947]
# Out:
# 'بسیار لطیف و ملاحت خاص دارد و از خود عکسش زیباتر و بهتر هست و با طیف رنگ ملایم و زیبا و چشم نواز… دیجی جان واقعا موجودش کن🙏🏻🙏🏻'

# %%
#check a comment to see the mark
df.comment.loc[80492]
# Out:
# 'حسگرش کار نمیکنه چرا😒😒😒\r\nاونجور که میگین نیست اصلا'

# %%
#check a comment to see the mark
df.comment.loc[73000]
# Out:
# '۴تا شمع۴۶۰۰۰۰هزار تومان😱'

# %%
#check a comment to see the mark
df.comment.loc[60805]
# Out:
# '😉✌✌✌✌✌✌✌✌✌✌✌✌✌✌'

# %%
#check a comment to see the mark
df.comment.loc[43291]
# Out:
# 'بارها غذا توش سوخته ولی به راحتی پاک شده 🙂\r\nتنها مشکلش اینه که درش سوراخ نداره و غذا سر میره'

# %%
#check a comment to see the mark
df.comment.loc[58620]
# Out:
# 'خیلی جنسش بده این قیمت ارزش نداره خیلی بده😠'

# %%
#check a comment to see the mark
df.comment.loc[6524]
# Out:
# 'فکر نکن پودرتو عوض کن 💝💝دورتو نهایت پاکیزگی💖💖اینجور که خودشون میگن😂😂'

# %%
#check a comment to see the mark
df.comment.loc[43291]
# Out:
# 'بارها غذا توش سوخته ولی به راحتی پاک شده 🙂\r\nتنها مشکلش اینه که درش سوراخ نداره و غذا سر میره'

# %%
# substring to be searched 
# sub ='\?'
  
# creating and passsing series to new column 
# df["?"]= df["comment"].str.find(sub) 
  
# display 
# df[df["?"] != -1.0]

# %%
x = ['?','؟','!','$','&','#','%','Emojies']
y = [len(res1),len(res2),len(res3),len(res4),len(res5),len(res6),len(res7),len(emo1)]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
# From here the plotting starts
plt.yticks(np.arange(min(y), max(y)+1, 250))
# plt.yticks(np.arange(0, 4200, 420))
plt.scatter(x, y, c='r', label='dot')
plt.plot(x, y, label='line')
plt.xlabel('Symbols')
plt.ylabel('Comment Number')
plt.title('Symbols plot')
plt.legend()
plt.show()

# %%
# plt.pie(y)

fig, ax = plt.subplots(figsize=(18, 9), subplot_kw=dict(aspect="equal"))

recipe = ["6 comment ?",
          "423 comment ؟",
          "4169 comment !",
          "1 comment $",
          "22 comment &",
          "68 comment #",
          "178 comment %",
          "42 comment emojies"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100000)
    return " "


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Symbols",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Symbol Rate in comments")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(24, 14), subplot_kw=dict(aspect="equal"))

recipe = ["? Symbol",
          "؟ Symbol" ,
          "! Symbol",
          "$ Symbol",
          "& Symbol",
          "# Symbol",
          "% Symbol",
          "emojies Symbol"]


data = [6, 423, 4169, 1, 22, 68, 178, 42]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=10)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/8. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Symbol Rate in comments")

plt.show()

# %% [markdown]
# ## Symbols in Titles

# %%
tres1 = df[df.title.astype(str).str.contains('\?')]
tres1
# Out:
#        product_id                   product_title  ...     advantages  disadvantages
# 76152      287997      ساعت هوشمند وی سریز مدل V8  ...  فیلد خالی است  فیلد خالی است
# 90343       76694  کرم ضد جوش AC.NET لامینین 30ml  ...  فیلد خالی است  فیلد خالی است
#
# [2 rows x 12 columns]

# %%
print('Number of comments title contain ? mark:' ,len(tres1))
# Out:
# Number of comments contain ? mark: 2

# %%
tres2 = df[df.title.astype(str).str.contains('\؟')]
tres2
# Out:
#        product_id  ...                     disadvantages
# 3427       670913  ...                     فیلد خالی است
# 4259       223856  ...                    ["چیزی ندیدم"]
# 4261       400827  ...  ["کار نکردن پالایش کیفیت خواب "]
# 4864       180578  ...                     فیلد خالی است
# 5732       175115  ...                         ["نوشتم"]
# ...           ...  ...                               ...
# 94924      580529  ...                     فیلد خالی است
# 95236      470248  ...                     فیلد خالی است
# 97444      451438  ...                     فیلد خالی است
# 99546      418657  ...                     فیلد خالی است
# 99738      259514  ...                     فیلد خالی است
#
# [81 rows x 12 columns]

# %%
print('Number of comments title contain ؟ mark:' ,len(tres2))
# Out:
# Number of comments title contain ؟ mark: 81

# %%
tres3 = df[df.title.astype(str).str.contains('!')]
tres3
# Out:
#        product_id  ...                                      disadvantages
# 154         84010  ...                                      فیلد خالی است
# 290        158804  ...  ["کمی پایین بودن سرعت ریفرش پیکسل های مشکی\r",...
# 365         92169  ...                                      فیلد خالی است
# 405        197264  ...                                      فیلد خالی است
# 407        224177  ...                   ["ظرفیت کمتر از میزان گفته شده"]
# ...           ...  ...                                                ...
# 99464      436237  ...                               ["نداشتن سکه ی جدا"]
# 99521      687028  ...                                       ["درب ضعیف"]
# 99721      520464  ...                                      فیلد خالی است
# 99738      259514  ...                                      فیلد خالی است
# 99867      397114  ...  ["کیفیت ساخت پائین،نه خیلی پائین\r","جنس نچندا...
#
# [908 rows x 12 columns]

# %%
print('Number of comments title contain ! mark:' ,len(tres3))
# Out:
# Number of comments title contain ! mark: 908

# %%
tres4 = df[df.title.astype(str).str.contains('\$')]
tres4
# Out:
#        product_id  ...  disadvantages
# 13928      554194  ...  فیلد خالی است
#
# [1 rows x 12 columns]

# %%
print('Number of comments title contain $ mark:' ,len(tres4))
# Out:
# Number of comments title contain $ mark: 1

# %%
tres5 = df[df.title.astype(str).str.contains('&')]
tres5
# Out:
#        product_id  ...              disadvantages
# 10130      431128  ...  ["خراب بودن کد دیجیتالی"]
# 16582      487061  ...              فیلد خالی است
# 25927      734482  ...              فیلد خالی است
# 31944      385243  ...                   ["هیچی"]
# 44734      385243  ...              فیلد خالی است
# 81108       62473  ...                    ["نوک"]
#
# [6 rows x 12 columns]

# %%
print('Number of comments title contain & mark:' ,len(tres5))
# Out:
# Number of comments title contain & mark: 6

# %%
tres6 = df[df.title.astype(str).str.contains('#')]
tres6
# Out:
#        product_id  ...                                   disadvantages
# 3597        70509  ...  ["سختی استفاده همزمان برنامه و Visual Studio"]
# 23502      345896  ...                           ["ضد آب..فست شارژ.."]
#
# [2 rows x 12 columns]

# %%
print('Number of comments title contain # mark:' ,len(tres6))
# Out:
# Number of comments title contain # mark: 2

# %%
tres7 = df[df.title.astype(str).str.contains('%')]
tres7
# Out:
#        product_id  ...                                      disadvantages
# 1422       459064  ...  ["فقط اینکه زود شارژش تموم می شه):\r","و دیر پ...
# 8126       176271  ...  ["ای کاش پد هم داشت!  \r","دکمه های سمت چپ کمی...
# 9020       581536  ...                                   ["برنج 0 %معطر"]
# 11557       20401  ...                                ["خط ریش زنه ضعیف"]
# 16198      623016  ...                                      فیلد خالی است
# 18120      665380  ...     ["کاش از مدل های مردانه برای خانم ها هم داشت"]
# 30273      106909  ...                                      فیلد خالی است
# 48530      708268  ...                                      فیلد خالی است
# 48686      364262  ...                                      فیلد خالی است
# 55150      349685  ...                                      فیلد خالی است
# 72368       61410  ...                           ["قیمت بالاتر از تعرفه"]
# 87552      251723  ...  ["شارژ دیر یاهچی اصلا شکل با چیز که فرستاده شد...
#
# ...

# %%
print('Number of comments title contain % mark:' ,len(tres7))
# Out:
# Number of comments title contain % mark: 12

# %%
#Emoji
temo1 = df[df.title.astype(str).str.contains(emoji_pattern)]
temo1
# Out:
#        product_id  ...                                      disadvantages
# 1713       111158  ...                                            ["هیچ"]
# 16550      695765  ...                                      فیلد خالی است
# 17056      603624  ...                                      فیلد خالی است
# 35804      319868  ...                                          ["ندیدم"]
# 35939      367103  ...                               ["باتریش و تاچ پد💔"]
# 43159      712617  ...                                      فیلد خالی است
# 58301      513439  ...                         ["رقيق \/ كم حجم \/ ضعيف"]
# 60805      564315  ...  ["قسمت خروجی و سریعتر شارژ میکنه رو سبز رنگ کن...
# 78420      653223  ...                                      فیلد خالی است
# 98388      832315  ...                               ["به درد بخور نیست"]
#
# [10 rows x 12 columns]

# %%
print('Number of comments title contain emojis:' ,len(temo1))
# Out:
# Number of comments title contain emojis: 10

# %%
x = ['?','؟','!','$','&','#','%','Emojies']
y = [len(tres1),len(tres2),len(tres3),len(tres4),len(tres5),len(tres6),len(tres7),len(temo1)]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
# From here the plotting starts
plt.yticks(np.arange(min(y), max(y)+1, 250))
# plt.yticks(np.arange(0, 4200, 420))
plt.scatter(x, y, c='r', label='dot')
plt.plot(x, y, label='line')
plt.xlabel('Symbols')
plt.ylabel('title Number')
plt.title('Symbols plot')
plt.legend()
plt.show()

# %%
# plt.pie(y)

fig, ax = plt.subplots(figsize=(18, 9), subplot_kw=dict(aspect="equal"))

recipe = ["2 title ?",
          "81 title ؟",
          "908 title !",
          "1 title $",
          "6 title &",
          "2 title #",
          "12 title %",
          "10 title emojies"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100000)
    return " "


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Symbols",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Symbol Rate in titles")

plt.show()

# %% [markdown]
# ## Symbols in Advantages

# %%
ares1 = df[df.advantages.astype(str).str.contains('\?')]
ares1
# Out:
#        product_id  ...                                      disadvantages
# 55097      420115  ...  ["شارژ نگه نمیداره\r","موقع پخش موزیک قطع و وص...
#
# [1 rows x 12 columns]

# %%
print('Number of advantages contain ? mark:' ,len(ares1))
# Out:
# Number of advantages contain ? mark: 1

# %%
ares2 = df[df.advantages.astype(str).str.contains('\؟')]
ares2
# Out:
#        product_id  ...                                      disadvantages
# 6216       104846  ...                                ["خیلی تند و تیزه"]
# 10742      580211  ...  ["صاف نکردن مو در دمای پایین یا متوسط\r","\r",...
# 11346      533339  ...              ["بعد از یکم استفاده سر درد میگیرین"]
# 17601       96715  ...                                      فیلد خالی است
# 42026      788928  ...                                          ["هیچ.."]
# 47146      101679  ...  ["سرعت بسیار مزخرف جوری که با گوشی نه میشه فیی...
# 47850      117387  ...                                      فیلد خالی است
# 57917      331596  ...                                      فیلد خالی است
# 68509      776766  ...                                    ["قیافه خسته "]
# 94081      270384  ...                                      فیلد خالی است
# 99000      795785  ...                             ["بدنه ضعیف\r","نویز"]
#
# [11 rows x 12 columns]

# %%
print('Number of advantages contain ؟ mark:' ,len(ares2))
# Out:
# Number of advantages contain ؟ mark: 11

# %%
ares3 = df[df.advantages.astype(str).str.contains('!')]
ares3
# Out:
#        product_id  ...                                      disadvantages
# 734        322991  ...                          ["خنک کاری خیلی کم ضعیف"]
# 819        142061  ...                ["سیمش در مقابل نیروی پیچشی ضعیفه"]
# 1054       512719  ...                             ["افتضاحه نخریید !! "]
# 1093       222634  ...                     ["محل قرار گیری سوکت هندزفری"]
# 1139        96131  ...  ["بعد 6 ماه استفاده فقط بنظرم یکم صدای دکمه ها...
# ...           ...  ...                                                ...
# 94391      548932  ...            ["احتمال بریدن دست در صورت بی احتیاطی"]
# 95878      318608  ...        ["رادیو بسیار ضعیف\r","جنس از پلاستیک خشک"]
# 96671      773340  ...                                       ["بى كيفيت"]
# 96868      200268  ...                                ["متریال بی کیفیت"]
# 97755      109810  ...  ["راهنمایی ناکافی برای نصب \r","اندازه های طبق...
#
# [143 rows x 12 columns]

# %%
print('Number of advantages contain ! mark:' ,len(ares3))
# Out:
# Number of advantages contain ! mark: 143

# %%
ares4 = df[df.advantages.astype(str).str.contains('\$')]
ares4
# Out:
# Empty DataFrame
# Columns: [product_id, product_title, title_en, user_id, likes, dislikes, verification_status, recommend, title, comment, advantages, disadvantages]
# Index: []

# %%
print('Number of advantages contain $ mark:' ,len(ares4))
# Out:
# Number of advantages contain $ mark: 0

# %%
ares5 = df[df.advantages.astype(str).str.contains('&')]
ares5
# Out:
#        product_id  ...                                      disadvantages
# 453        174307  ...                            ["هی باید دستمال کشید"]
# 22110      506787  ...            ["کیفیت کم ساخت بدنه\r","گرم شدن سریع"]
# 56327      587204  ...        ["کیفیت معمولی اسپیکر\r","قیمت نسبتا زیاد"]
# 66643       14994  ...                                       ["نبود لنز"]
# 95383      298696  ...  ["جنس بدنه پلاستیک ولی مهم نیست\r","لولا ها کی...
#
# [5 rows x 12 columns]

# %%
print('Number of advantages contain & mark:' ,len(ares5))
# Out:
# Number of advantages contain & mark: 5

# %%
ares6 = df[df.advantages.astype(str).str.contains('#')]
ares6
# Out:
# Empty DataFrame
# Columns: [product_id, product_title, title_en, user_id, likes, dislikes, verification_status, recommend, title, comment, advantages, disadvantages]
# Index: []

# %%
print('Number of advantages contain # mark:' ,len(ares6))
# Out:
# Number of advantages contain # mark: 0

# %%
ares7 = df[df.advantages.astype(str).str.contains('%')]
ares7
# Out:
#        product_id  ...                                      disadvantages
# 290        158804  ...  ["کمی پایین بودن سرعت ریفرش پیکسل های مشکی\r",...
# 880        433637  ...  ["بهینه نمودن آب خروجی فقط تا 40%\r","پایین نی...
# 1216       539796  ...  ["نیاز به صبر و شکیبایی بالا برای گرفتن نتیجه ...
# 30350      175321  ...  ["گران و کمیاب بودن بازی\r","عدم پشتیبانی توسط...
# 34244      119453  ...  ["وزن تا حدودی زیاد\r","زمان شارژ شدن خود پاور...
# 53203       82138  ...                     ["عدم امکان حجم بالاتر محصول"]
# 73187      339175  ...                                          ["ندیدم"]
# 75366      560043  ...                                          ["ندارد"]
# 75532      657807  ...                                  ["بدنه پلاستیک "]
# 84725      506377  ...                          ["مصرف برق به نسبت بالا"]
# 96920      319868  ...                                     ["سنگینی وزن"]
# 97382       74303  ...                                          ["نداره"]
#
# ...

# %%
print('Number of advantages contain % mark:' ,len(ares7))
# Out:
# Number of advantages contain % mark: 12

# %%
#Emoji
aemo1 = df[df.advantages.astype(str).str.contains(emoji_pattern)]
aemo1
# Out:
#        product_id  ...                                      disadvantages
# 25567      580224  ...                                    ["طراحی زیبا "]
# 45139      125586  ...  ["انگار خوب پرس نشده ولي ژت رژگونه رو روش ميزن...
#
# [2 rows x 12 columns]

# %%
print('Number of advantages contain emoji mark:' ,len(aemo1))
# Out:
# Number of advantages contain % mark: 2

# %%
df.advantages.loc[25567]
# Out:
# '["طراحی زیبا و کاربرد رنگ های شاد استفاده از این روسری را لذت بخش کرده 😊"]'

# %%
x = ['?','؟','!','$','&','#','%','Emojies']
y = [len(ares1),len(ares2),len(ares3),len(ares4),len(ares5),len(ares6),len(ares7),len(aemo1)]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
# From here the plotting starts
plt.yticks(np.arange(min(y), max(y)+1, 250))
# plt.yticks(np.arange(0, 4200, 420))
plt.scatter(x, y, c='r', label='dot')
plt.plot(x, y, label='line')
plt.xlabel('Symbols')
plt.ylabel('advantages Number')
plt.title('Symbols plot')
plt.legend()
plt.show()

# %%
# plt.pie(y)

fig, ax = plt.subplots(figsize=(18, 9), subplot_kw=dict(aspect="equal"))

recipe = ["1 advantages ?",
          "11 advantages ؟",
          "143 advantages !",
          "0 advantages $",
          "5 advantages &",
          "0 advantages #",
          "12 advantages %",
          "2 advantages emojies"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100000)
    return " "


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Symbols",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Symbol Rate in advantages")

plt.show()

# %% [markdown]
# ##Symbols in Disadvantages

# %%
dres1 = df[df.disadvantages.astype(str).str.contains('\?')]
dres1
# Out:
#        product_id  ... disadvantages
# 51827      465999  ...   ["???????"]
#
# [1 rows x 12 columns]

# %%
print('Number of disadvantages contain ? mark:' ,len(dres1))
# Out:
# Number of disadvantages contain ? mark: 1

# %%
dres2 = df[df.disadvantages.astype(str).str.contains('\؟')]
dres2
# Out:
#        product_id  ...                                      disadvantages
# 2418       283799  ...                                           ["..؟."]
# 9764       481454  ...  ["رنگ ایرانی بسیار کم کیفیت تر از نمونه ی کره ...
# 11661      263451  ...  ["برد کم.نور زوم نمیشه.واقعا چرا زدهین برد۱۰۰۰...
# 14493      187652  ...    [" نمیدونم سوهانش کند بشه چطور میشه عوضش کرد؟"]
# 18037      731652  ...                 ["شاید مارک روی جیب!؟ \r","ندیدم"]
# 18976      616370  ...        ["چرا دمای بدن رو 36 درجه نشان میدهد؟!!!!"]
# 19588      139648  ...                              ["قیمت وحشتناک...!؟"]
# 19614      637302  ...                                     ["مگه داریم؟"]
# 22402      336323  ...                        ["مگه میشه سونی بد باشه؟!"]
# 25053      223550  ...                    ["نداره آقا دنبال چی میگردین؟"]
# 25607      641450  ...                                   ["مگه داره؟؟؟؟"]
# 30880      545520  ...                 ["جواب درد بیمار ما را کی میدهد؟"]
# ...

# %%
print('Number of disadvantages contain ؟ mark:' ,len(dres2))
# Out:
# Number of disadvantages contain ؟ mark: 31

# %%
dres3 = df[df.disadvantages.astype(str).str.contains('!')]
dres3
# Out:
#        product_id  ...                                      disadvantages
# 61          64043  ...               ["کشیدگی تصاویری که کشیده نیستند !"]
# 140         91264  ...                           ["ضعف ضعف!!!نه نه اصلآ"]
# 208        157450  ...      ["رنگ قرمزش یکم شبیه صورتیه !!! ( کم رنگه )"]
# 316        104647  ...  ["جای قرار گرفتن باتری در بسته بندی خالیست و د...
# 454        162704  ...                                 ["انصافا نداره! "]
# ...           ...  ...                                                ...
# 97594      837135  ...                                         ["گرونه!"]
# 98265      420253  ...     ["فقط من مشکی گفتم دیجی کالا قهوه ای فرستاد!"]
# 98267      268080  ...  ["جنس قاب جوریه که رنگش کنده میشه!\r","یه بدی ...
# 99653      458727  ...              ["تاریخ انقضای کالا ۱۰\/۲۰۱۹ بود!!!"]
# 99983       87150  ...  ["پایین بودن ظرفیت واقعی در حدود ۴۰۰۰\r","زمان...
#
# [284 rows x 12 columns]

# %%
print('Number of disadvantages contain ! mark:' ,len(dres3))
# Out:
# Number of disadvantages contain ! mark: 284

# %%
dres4 = df[df.disadvantages.astype(str).str.contains('\$')]
dres4
# Out:
# Empty DataFrame
# Columns: [product_id, product_title, title_en, user_id, likes, dislikes, verification_status, recommend, title, comment, advantages, disadvantages]
# Index: []

# %%
print('Number of disadvantages contain $ mark:' ,len(dres4))
# Out:
# Number of disadvantages contain $ mark: 0

# %%
dres5 = df[df.disadvantages.astype(str).str.contains('&')]
dres5
# Out:
#        product_id  ...                                      disadvantages
# 75773       91952  ...  ["سریع داغ میشد\r","Plug & Play نبود. مجبور شد...
#
# [1 rows x 12 columns]

# %%
print('Number of disadvantages contain & mark:' ,len(dres5))
# Out:
# Number of disadvantages contain & mark: 1

# %%
dres6 = df[df.disadvantages.astype(str).str.contains('#')]
dres6
# Out:
#        product_id  ...                                      disadvantages
# 72560      748522  ...  ["خیلی خیلی سایزش برای دست آدم بالغ بزرگه،بهتر...
#
# [1 rows x 12 columns]

# %%
print('Number of disadvantages contain # mark:' ,len(dres6))
# Out:
# Number of disadvantages contain # mark: 1

# %%
dres7 = df[df.disadvantages.astype(str).str.contains('%')]
dres7
# Out:
#        product_id  ...                                      disadvantages
# 880        433637  ...  ["بهینه نمودن آب خروجی فقط تا 40%\r","پایین نی...
# 2951       175321  ...  ["تنها اشکالی که بر این کنسول مشه گرفت بازی ها...
# 5075       337536  ...  ["خیلی گنده.ست\r","عدم وضوح صدای مطلوب در صدای...
# 9020       581536  ...                                   ["برنج 0 %معطر"]
# 53187      739534  ...                              ["یکم بیشتر از 32 %"]
# 60108      594793  ...  ["سنسور هاش بعضی اوقات درست نشون نمیده اما تقر...
# 64617      114902  ...  ["از روز اول مدت زمان شارژ طولانی و نگهداری کم...
# 65405       74122  ...  ["باتریش تو 70% تمام میشه و خاموش می کنه بدون ...
# 99794      809940  ...  ["قیمت زیاد نسبت به کیفیت\r","1%هم گوشت نداره ...
# 99943      859802  ...                     ["شارژ نمی کنه تو ۱ ساعت ۱۵%"]
#
# [10 rows x 12 columns]

# %%
print('Number of disadvantages contain % mark:' ,len(dres7))
# Out:
# Number of disadvantages contain % mark: 10

# %%
#Emoji
demo1 = df[df.disadvantages.astype(str).str.contains(emoji_pattern)]
demo1
# Out:
#        product_id  ...                                      disadvantages
# 3015       380207  ...  ["اصلا کار نداد نمیدونم تعمیر می‌شه فیوز داره ...
# 32792      145186  ...                              ["هنوز دستم نرسیده😅"]
# 43322      106164  ...                              ["چسبندگی خیلی قوی😕"]
# 48846      682694  ...                                          ["هیچی😊"]
# 62010      263680  ...              ["پلمپ کرم پودر موقع تحویل باز بود😐"]
# 76148      671068  ...  ["عدم حالت استند بای برای زمانی که استفاده نمی...
# 86953      443628  ...                                  ["من که ندیدم 😉"]
# 95239      251733  ...                                       ["ندارد😍😍😍"]
#
# [8 rows x 12 columns]

# %%
print('Number of disadvantages contain emoji mark:' ,len(demo1))
# Out:
# Number of disadvantages contain emoji mark: 8

# %%
x = ['?','؟','!','$','&','#','%','Emojies']
y = [len(dres1),len(dres2),len(dres3),len(dres4),len(dres5),len(dres6),len(dres7),len(demo1)]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
# From here the plotting starts
plt.yticks(np.arange(min(y), max(y)+1, 250))
# plt.yticks(np.arange(0, 4200, 420))
plt.scatter(x, y, c='r', label='dot')
plt.plot(x, y, label='line')
plt.xlabel('Symbols')
plt.ylabel('disadvantages Number')
plt.title('Symbols plot')
plt.legend()
plt.show()

# %%
# plt.pie(y)

fig, ax = plt.subplots(figsize=(18, 9), subplot_kw=dict(aspect="equal"))

recipe = ["1 disadvantages ?",
          "31 disadvantages ؟",
          "284 disadvantages !",
          "0 disadvantages $",
          "1 disadvantages &",
          "1 disadvantages #",
          "10 disadvantages %",
          "8 disadvantages emojies"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100000)
    return " "


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Symbols",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Symbol Rate in disadvantages")

plt.show()
